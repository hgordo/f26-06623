# %% [markdown]
# Practice questions for Markdown
# ===============================
#
# Run this cell, then answer the questions. Your answers will automatically be saved in the state.json file. Do not delete this file.

# %%
from pathlib import Path

try:
    import google.colab

    repo = Path("/content/f26-06623")

    if not repo.exists():
        # !git clone -q --depth 1 --filter=blob:none --sparse \
            https://github.com/hgordo/f26-06623.git /content/f26-06623

        # !git -C /content/f26-06623 sparse-checkout set f26-06623/lectures/01-colab

    # %cd /content/f26-06623/f26-06623/lectures/01-colab

except ImportError:
    pass
# Out:
# /content/f26-06623/f26-06623/lectures/01-colab

# %%
# %run markdown_practice.py
