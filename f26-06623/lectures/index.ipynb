# %% [markdown]
# # Index
#
# Note these links only work in the notebook. The links in the [rendered HTML pages](https://kitchingroup.cheme.cmu.edu/f23-06623/lectures/index.html) do not work.

# %%
# %run ./generate_index.ipynb
generate_index()

# %% [markdown]
# # Tags

# %%
# %run ./generate_index.ipynb
generate_tags()
# Out:
# ##  #event
# -   [05-nth-odes/05-nth-odes.ipynb](05-nth-odes/05-nth-odes.ipynb)
# ##  #function
# -   [01-colab/01-colab.ipynb](01-colab/01-colab.ipynb)
